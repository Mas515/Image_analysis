# %% [markdown]
# # DataFrame cleaning, normalization and feature selection

# %%
import pandas as pd
import numpy as np
import pycytominer
import pickle

# %% [markdown]
# ## Import the raw data table with the metadata

# %%
compartments = ['Nuclei', 'Cytoplasm', 'Cells']

# %%
path = r'G:\My Drive\Analysis\DILI\workspace\backend'

# %%
# plate = r'\220617_090443_Plate 1_DILI'
# plate = r'\220607_092050_Plate 1_DILI'
plate = r'\220608_152238_Plate 1_DILI'

# %%
list_cols = ['Metadata', 'FileName', 'PathName']

# %%
metadata = pd.read_csv('G:\My Drive\Analysis\DILI\workspace\metadata\metadata.csv')

# %% [markdown]
# ## Join all compartments aggregated by well
#
# Here, we take each csv table (Nuclei, Cell, Cytoplasm) and open it into a df.

# %%
df_all = []
for cmpt in compartments:
    df = pd.read_csv(path + plate + cmpt + ".csv", low_memory=False)
    # print(df)
    #pop metadata and save it to use later
    list_to_pop = ['Metadata_Plate', 'Metadata_Well']
    meta = [df.pop(col) for col in list_to_pop]
    df_meta = pd.concat(meta, axis=1)
    list_df = list(df.columns)
    #pop all metadata, filename and pathname cols
    for name in list_cols:
        for cols in range(len(list_df)):
            if name in list_df[cols]:
                df.drop(list_df[cols], axis='columns', inplace=True)
                # print(list_df[cols])
    list_df = list(df.columns)
    #here we just add Nuclei, Cell or Cytoplasm before each col name
    for cols in range(len(list_df)):
        df.rename(columns={list_df[cols]: cmpt+"_"+list_df[cols]}, inplace=True, errors='raise') 
    df_after = pd.concat([df, df_meta], axis = 'columns')
    features = pycytominer.cyto_utils.infer_cp_features(df_after,compartments=compartments)
    df_ag = pycytominer.aggregate(df_after, features=features, operation = 'median', float_format = "%.3g")
    df_all.append(df_ag)

# %% [markdown]
# # Join dataset plate level

# %%
df = pd.concat(df_all, axis=1) #create a final dataframe from df_all list above

# %%
df = df.loc[:,~df.columns.duplicated()].copy() #exclude duplicate cols

# %%
print(df.shape)
# Out:
# (58, 1817)

# %%
df.head()
# Out:
#           Metadata_Plate Metadata_Well  Nuclei_ImageNumber  \
# 0  220608_152238_Plate 1           B10                11.0
# 1  220608_152238_Plate 1           B11                37.0
# 2  220608_152238_Plate 1            B3                61.0
# 3  220608_152238_Plate 1            B4                87.0
# 4  220608_152238_Plate 1            B5               112.0
#
#    Nuclei_ObjectNumber  Nuclei_AreaShape_Area  \
# 0                  8.0                 4196.5
# 1                 15.0                 2847.0
# 2                 18.0                 2649.0
# 3                 19.5                 2851.5
# 4                 18.0                 2652.0
#
#    Nuclei_AreaShape_BoundingBoxArea  Nuclei_AreaShape_BoundingBoxMaximum_X  \
# 0                            5484.0                                  665.0
# 1                            3780.0                                  665.0
# 2                            3510.0                                  571.0
# 3                            3776.0                                  620.5
# 4                            3480.0                                  673.0
#
#    Nuclei_AreaShape_BoundingBoxMaximum_Y  \
# 0                                  525.5
# 1                                  484.0
# 2                                  487.0
# 3                                  478.0
# 4                                  500.0
#
#    Nuclei_AreaShape_BoundingBoxMinimum_X  \
# 0                                  595.5
# 1                                  600.0
# 2                                  507.0
# 3                                  558.0
# 4                                  615.5
#
#    Nuclei_AreaShape_BoundingBoxMinimum_Y  ...  \
# 0                                  451.0  ...
# 1                                  424.5  ...
# 2                                  424.0  ...
# 3                                  421.5  ...
# 4                                  442.5  ...
#
#    Cells_Texture_Variance_CorrPI_10_02_256  \
# 0                               215.366229
# 1                               148.839653
# 2                               157.878923
# 3                               125.388832
# 4                               216.938099
#
#    Cells_Texture_Variance_CorrPI_10_03_256  \
# 0                               210.070175
# 1                               150.502579
# 2                               158.643516
# 3                               126.723466
# 4                               219.904319
#
#    Cells_Texture_Variance_CorrPI_20_00_256  \
# 0                               211.701579
# 1                               150.047433
# 2                               163.154688
# 3                               128.192027
# 4                               224.152057
#
#    Cells_Texture_Variance_CorrPI_20_01_256  \
# 0                               215.698091
# 1                               152.647744
# 2                               168.275550
# 3                               131.446936
# 4                               225.925791
#
#    Cells_Texture_Variance_CorrPI_20_02_256  \
# 0                               212.603268
# 1                               153.241051
# 2                               165.339165
# 3                               129.236769
# 4                               225.041882
#
#    Cells_Texture_Variance_CorrPI_20_03_256  \
# 0                               211.439531
# 1                               151.534075
# 2                               169.099120
# 3                               130.477090
# 4                               231.726194
#
#    Cells_Texture_Variance_CorrPI_5_00_256  \
# 0                              213.945414
# 1                              147.293229
# 2                              154.939880
# 3                              122.708104
# 4                              215.108946
#
#    Cells_Texture_Variance_CorrPI_5_01_256  \
# 0                              212.258430
# 1                              147.157296
# 2                              156.587124
# 3                              123.346758
# 4                              215.091030
#
#    Cells_Texture_Variance_CorrPI_5_02_256  \
# 0                              212.516874
# 1                              147.330577
# 2                              155.874534
# 3                              124.450071
# 4                              215.064808
#
#    Cells_Texture_Variance_CorrPI_5_03_256
# 0                              213.238307
# 1                              148.230023
# 2                              154.328912
# 3                              124.706196
# 4                              215.946016
#
# [5 rows x 1817 columns]

# %% [markdown]
# # Annotate
#
# - Careful here with the name of the join_on columns: if they have the SAME NAME, pycytominer will drop BOTH.
# - Pycytominer has a "add_metadata_id_to_platemap" parameter that adds "Metadata_" prefix to your metadata columns. Change to False if you already have the prefix.

# %%
df_an = pycytominer.annotate(df, metadata, join_on = ['Metadata_Wells', 'Metadata_Well'], add_metadata_id_to_platemap = True)

# %%
df_an.head()
# Out:
#    Metadata_Concentration Metadata_Cell Metadata_Compound  \
# 0                     1.0          Huh7           Aspirin
# 1                    10.0          Huh7           Aspirin
# 2                     0.2          Huh7        Amiodarone
# 3                     2.0          Huh7        Amiodarone
# 4                     1.0          Huh7  Cyclophosphamide
#
#                         Metadata_moa Metadata_DILI-concern  \
# 0                      COX inhibitor     Less-DILI-Concern
# 1                      COX inhibitor     Less-DILI-Concern
# 2  sodium/potassium-ATPase inhibitor     Most-DILI-Concern
# 3  sodium/potassium-ATPase inhibitor     Most-DILI-Concern
# 4                    DNA alkylation    \tLess-DILI-Concern
#
#    Metadata_Severity Class         Metadata_Plate Metadata_Well  \
# 0                        0  220608_152238_Plate 1            B3
# 1                        0  220608_152238_Plate 1            B4
# 2                        8  220608_152238_Plate 1            B5
# 3                        8  220608_152238_Plate 1            B6
# 4                        5  220608_152238_Plate 1            B7
#
#    Nuclei_ImageNumber  Nuclei_ObjectNumber  ...  \
# 0                61.0                 18.0  ...
# 1                87.0                 19.5  ...
# 2               112.0                 18.0  ...
# 3               137.0                 17.0  ...
# 4               163.0                 17.0  ...
#
#    Cells_Texture_Variance_CorrPI_10_02_256  \
# 0                               157.878923
# 1                               125.388832
# 2                               216.938099
# 3                               281.084116
# 4                               159.982108
#
#    Cells_Texture_Variance_CorrPI_10_03_256  \
# 0                               158.643516
# 1                               126.723466
# 2                               219.904319
# 3                               284.057437
# 4                               161.206634
#
#    Cells_Texture_Variance_CorrPI_20_00_256  \
# 0                               163.154688
# 1                               128.192027
# 2                               224.152057
# 3                               284.470988
# 4                               159.627931
#
#    Cells_Texture_Variance_CorrPI_20_01_256  \
# 0                               168.275550
# 1                               131.446936
# 2                               225.925791
# 3                               287.877273
# 4                               167.744992
#
#    Cells_Texture_Variance_CorrPI_20_02_256  \
# 0                               165.339165
# 1                               129.236769
# 2                               225.041882
# 3                               291.492034
# 4                               163.380125
#
#    Cells_Texture_Variance_CorrPI_20_03_256  \
# 0                               169.099120
# 1                               130.477090
# 2                               231.726194
# 3                               286.111390
# 4                               164.382678
#
#    Cells_Texture_Variance_CorrPI_5_00_256  \
# 0                              154.939880
# 1                              122.708104
# 2                              215.108946
# 3                              278.033318
# 4                              159.701625
#
#    Cells_Texture_Variance_CorrPI_5_01_256  \
# 0                              156.587124
# 1                              123.346758
# 2                              215.091030
# 3                              279.199912
# 4                              159.640378
#
#    Cells_Texture_Variance_CorrPI_5_02_256  \
# 0                              155.874534
# 1                              124.450071
# 2                              215.064808
# 3                              276.583569
# 4                              159.636862
#
#    Cells_Texture_Variance_CorrPI_5_03_256
# 0                              154.328912
# 1                              124.706196
# 2                              215.946016
# 3                              279.335872
# 4                              158.831950
#
# [5 rows x 1823 columns]

# %% [markdown]
# ## Normalize data using pycytominer
#
# - Pycytominer has a caveat - it will normalize the Location columns, because they have the Compartments as a prefix (for example, 'Nuclei_Location_Center_X'.)
# - For us, maintaining these columns with their original value is important to be able to plot single-cell, and have their localization numbers as it is, because they point to locations in the image.
# - That's why we retrieve metadata cols and add Nuclei_Location cols as meta_features, so we don't normalize them.

# %%
#giving cols_keep as a paramter for meta_features. But pycytominer is renaming the Nuclei_Location_Center_Y to Nuclei_Location_Center_Y_x 
# meta_cols = pycytominer.cyto_utils.features.infer_cp_features(df_an, metadata=True)
# cols_keep = meta_cols + ['Nuclei_Location_Center_X', 'Nuclei_Location_Center_Y']

# %%
df_loc = df_an[['Nuclei_Location_Center_X', 'Nuclei_Location_Center_Y']]
df_an2 = df_an.drop(columns=['Nuclei_Location_Center_X', 'Nuclei_Location_Center_Y'])

# %%
#use pycytominer to normalize columns
#here the default is to ignore only the metadata columns, so it will normalize everything else "Metadata_Compound == 'Ctrl'"  
df_norm = pycytominer.normalize(df_an2, method = 'mad_robustize', mad_robustize_epsilon = 0, samples = "Metadata_Compound == 'DMSO'")
# Out:
# c:\Users\fossa\Anaconda3\envs\pycytominer\lib\site-packages\scipy\stats\_stats_py.py:2894: RuntimeWarning: invalid value encountered in subtract
#   mad = np.median(np.abs(x - med))

# %%
df_all = pd.concat([df_norm, df_loc], axis = 1) #join the location_columns with the normalized df

# %%
df_all.head()
# Out:
#    Metadata_Concentration Metadata_Cell Metadata_Compound  \
# 0                     1.0          Huh7           Aspirin
# 1                    10.0          Huh7           Aspirin
# 2                     0.2          Huh7        Amiodarone
# 3                     2.0          Huh7        Amiodarone
# 4                     1.0          Huh7  Cyclophosphamide
#
#                         Metadata_moa Metadata_DILI-concern  \
# 0                      COX inhibitor     Less-DILI-Concern
# 1                      COX inhibitor     Less-DILI-Concern
# 2  sodium/potassium-ATPase inhibitor     Most-DILI-Concern
# 3  sodium/potassium-ATPase inhibitor     Most-DILI-Concern
# 4                    DNA alkylation    \tLess-DILI-Concern
#
#    Metadata_Severity Class         Metadata_Plate Metadata_Well  \
# 0                        0  220608_152238_Plate 1            B3
# 1                        0  220608_152238_Plate 1            B4
# 2                        8  220608_152238_Plate 1            B5
# 3                        8  220608_152238_Plate 1            B6
# 4                        5  220608_152238_Plate 1            B7
#
#    Nuclei_ImageNumber  Nuclei_ObjectNumber  ...  \
# 0           -3.050107            -3.372454  ...
# 1           -2.979678            -2.360718  ...
# 2           -2.911958            -3.372454  ...
# 3           -2.844238            -4.046945  ...
# 4           -2.773809            -4.046945  ...
#
#    Cells_Texture_Variance_CorrPI_20_00_256  \
# 0                                 3.470718
# 1                                 1.753401
# 2                                 6.466825
# 3                                 9.429607
# 4                                 3.297489
#
#    Cells_Texture_Variance_CorrPI_20_01_256  \
# 0                                 3.942599
# 1                                 2.013983
# 2                                 6.961589
# 3                                10.205823
# 4                                 3.914815
#
#    Cells_Texture_Variance_CorrPI_20_02_256  \
# 0                                 3.487385
# 1                                 1.779847
# 2                                 6.311150
# 3                                 9.454049
# 4                                 3.394728
#
#    Cells_Texture_Variance_CorrPI_20_03_256  \
# 0                                 3.609819
# 1                                 1.828637
# 2                                 6.498073
# 3                                 9.006226
# 4                                 3.392305
#
#    Cells_Texture_Variance_CorrPI_5_00_256  \
# 0                                3.169775
# 1                                1.498379
# 2                                6.289875
# 3                                9.552852
# 4                                3.416698
#
#    Cells_Texture_Variance_CorrPI_5_01_256  \
# 0                                3.065453
# 1                                1.438532
# 2                                5.928877
# 3                                9.066632
# 4                                3.214892
#
#    Cells_Texture_Variance_CorrPI_5_02_256  \
# 0                                3.501375
# 1                                1.720114
# 2                                6.856511
# 3                               10.343635
# 4                                3.714639
#
#    Cells_Texture_Variance_CorrPI_5_03_256  Nuclei_Location_Center_X  \
# 0                                3.200141                538.008168
# 1                                1.629242                590.097303
# 2                                6.467709                641.863063
# 3                                9.829285                594.346481
# 4                                3.438938                618.873067
#
#    Nuclei_Location_Center_Y
# 0                458.608063
# 1                450.250820
# 2                470.249426
# 3                428.523968
# 4                462.362828
#
# [5 rows x 1823 columns]

# %% [markdown]
# # Save plate

# %%
df_all.to_pickle(path + plate + '_Normalized' + '.pkl')
